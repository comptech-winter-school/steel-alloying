# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings("ignore")

# %%
df = pd.read_table('data.csv', sep=';', index_col=0, decimal=',')
df.head()
# Out:
#           nplv                   DT  МАРКА ПРОФИЛЬ  t вып-обр  t обработка  \
# 0  г6837?3<87?  2070-06-21 00:14:00  Э76ХФ     Р65       29.0    45.366667
# 1  г683863<886  2070-06-21 01:07:00  Э76ХФ     Р65       26.0    44.066667
# 2  г683863<887  2070-06-21 02:00:00  Э76ХФ     Р65       24.0    43.350000
# 3  г683863<888  2070-06-21 02:58:00  Э76ХФ     Р65       17.0    46.183333
# 4  г683863<889  2070-06-21 03:50:00  Э76ХФ     Р65       20.0    48.500000
#
#    t под током  t продувка  ПСН гр.  чист расход C  ...  химшлак первый MnO_1  \
# 0    24.400000   41.033333      NaN       0.456460  ...                  0.12
# 1    13.866667   44.066667      NaN       0.359285  ...                  0.14
# 2    17.950000   43.350000      NaN       0.331665  ...                  0.12
# 3    19.816667   46.183333      NaN       0.377945  ...                  0.11
# 4    17.033333   48.500000      NaN       0.389875  ...                  0.12
#
#    химшлак первый R_1  химшлак первый SiO2_1  химшлак последний Al2O3  \
# 0                 2.6                    NaN                      NaN
# 1                 2.2                    NaN                      NaN
# 2                 2.6                    NaN                      NaN
# 3                 2.4                    NaN                      NaN
# 4                 2.4                    NaN                      NaN
#
#    химшлак последний CaO  химшлак последний FeO  химшлак последний MgO  \
# 0                   53.4                    1.0                    5.8
# 1                   59.3                    0.6                    4.1
# 2                   57.2                    0.5                    8.1
# 3                   60.3                    0.5                    6.3
# 4                   60.3                    0.6                    4.5
#
#    химшлак последний MnO  химшлак последний R  химшлак последний SiO2
# 0                   0.15                  2.6                     NaN
# 1                   0.11                  2.3                     NaN
# 2                   0.13                  2.3                     NaN
# 3                   0.12                  2.6                     NaN
# 4                   0.09                  2.5                     NaN
#
# [5 rows x 84 columns]

# %%
df.shape # 7041 наблюдения, 84 колонки
# Out:
# (7041, 84)

# %%
df = df[df['t вып-обр'].notna()] # удаляем пустые строки

# %%
df.shape
# Out:
# (6444, 84)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6444 entries, 0 to 7040
# Data columns (total 84 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   nplv                            6444 non-null   object
#  1   DT                              6444 non-null   object
#  2   МАРКА                           6444 non-null   object
#  3   ПРОФИЛЬ                         6444 non-null   object
#  4   t вып-обр                       6444 non-null   float64
#  5   t обработка                     6440 non-null   float64
#  6   t под током                     6440 non-null   float64
#  7   t продувка                      6444 non-null   float64
#  8   ПСН гр.                         5249 non-null   float64
#  9   чист расход C                   6435 non-null   float64
#  10  чист расход Cr                  5883 non-null   float64
#  11  чист расход Mn                  6431 non-null   float64
#  12  чист расход Si                  6431 non-null   float64
#  13  чист расход V                   6178 non-null   float64
#  14  температура первая              6436 non-null   float64
#  15  температура последняя           6436 non-null   float64
#  16  Ar (интенс.)                    6426 non-null   float64
#  17  N2 (интенс.)                    1389 non-null   float64
#  18  эл. энергия (интенс.)           6440 non-null   float64
#  19  произв жидкая сталь             6444 non-null   float64
#  20  произв количество обработок     6444 non-null   float64
#  21  произв  количество плавок       6444 non-null   float64
#  22  произв количество плавок (цел)  6444 non-null   float64
#  23  расход газ Ar                   6426 non-null   float64
#  24  расход газ  N2                  1389 non-null   float64
#  25  расход C пров.                  724 non-null    float64
#  26  сыпуч известь РП                4770 non-null   float64
#  27  сыпуч кварцит                   13 non-null     float64
#  28  сыпуч кокс пыль УСТК            6422 non-null   float64
#  29  сыпуч  кокс. мелочь (сух.)      7 non-null      float64
#  30  сыпуч  кокс. мелочь КМ1         6307 non-null   float64
#  31  сыпуч  шпат плав.               5910 non-null   float64
#  32  ферспл CaC2                     6244 non-null   float64
#  33  ферспл FeMo                     33 non-null     float64
#  34  ферспл FeSi-75                  5 non-null      float64
#  35  ферспл FeV азот.                383 non-null    float64
#  36  ферспл  FeV-80                  6179 non-null   float64
#  37  ферспл  Mn5Si65Al0.5            6400 non-null   float64
#  38  ферспл  Ni H1 пласт.            82 non-null     float64
#  39  ферспл SiMn18                   6398 non-null   float64
#  40  ферспл  ферванит                1017 non-null   float64
#  41  ферспл  фх850А                  5883 non-null   float64
#  42  эл. энергия                     6440 non-null   float64
#  43  химсталь первый Al_1            6444 non-null   float64
#  44  химсталь первый C_1             6444 non-null   float64
#  45  химсталь первый Cr_1            6444 non-null   float64
#  46  химсталь первый Cu_1            6444 non-null   float64
#  47  химсталь первый Mn_1            6444 non-null   float64
#  48  химсталь первый Mo_1            6443 non-null   float64
#  49  химсталь первый N_1             6443 non-null   float64
#  50  химсталь первый Ni_1            6444 non-null   float64
#  51  химсталь первый P_1             6444 non-null   float64
#  52  химсталь первый S_1             6444 non-null   float64
#  53  химсталь первый Si_1            6444 non-null   float64
#  54  химсталь первый Ti_1            6444 non-null   float64
#  55  химсталь первый V_1             6444 non-null   float64
#  56  химсталь последний Al           6444 non-null   float64
#  57  химсталь последний C            6444 non-null   float64
#  58  химсталь последний Ca           6218 non-null   float64
#  59  химсталь последний Cr           6444 non-null   float64
#  60  химсталь последний Cu           6444 non-null   float64
#  61  химсталь последний Mn           6444 non-null   float64
#  62  химсталь последний Mo           6444 non-null   float64
#  63  химсталь последний N            6442 non-null   float64
#  64  химсталь последний Ni           6444 non-null   float64
#  65  химсталь последний P            6444 non-null   float64
#  66  химсталь последний S            6444 non-null   float64
#  67  химсталь последний Si           6444 non-null   float64
#  68  химсталь последний Ti           6444 non-null   float64
#  69  химсталь последний V            6444 non-null   float64
#  70  химшлак первый Al2O3_1          4742 non-null   float64
#  71  химшлак первый CaO_1            6444 non-null   float64
#  72  химшлак первый FeO_1            6444 non-null   float64
#  73  химшлак первый MgO_1            6443 non-null   float64
#  74  химшлак первый MnO_1            6444 non-null   float64
#  75  химшлак первый R_1              6444 non-null   float64
#  76  химшлак первый SiO2_1           4742 non-null   float64
#  77  химшлак последний Al2O3         4742 non-null   float64
#  78  химшлак последний CaO           6444 non-null   float64
#  79  химшлак последний FeO           6444 non-null   float64
#  80  химшлак последний MgO           6443 non-null   float64
#  81  химшлак последний MnO           6444 non-null   float64
#  82  химшлак последний R             6444 non-null   float64
#  83  химшлак последний SiO2          4742 non-null   float64
# dtypes: float64(80), object(4)
# memory usage: 4.2+ MB

# %%
df['произв количество обработок'].value_counts()
# Out:
# 1.0    6391
# 2.0      48
# 3.0       5
# Name: произв количество обработок, dtype: int64

# %%
df['ПРОФИЛЬ'].value_counts() # физически не связано с составом
# Out:
# Р65                                 5867
# ОР65                                 217
# 60E1                                  94
# UIC54                                 52
# Рельсы трамвайные                     49
# Р50                                   44
# Шар заг d шара 80-100 мм 2,3 гр.      44
# 136 RE                                17
# Шар заг d шара 80-100 мм 4 гр.        17
# Шары мелющие d 80-100 мм              14
# 54E1                                   9
# НЕТ                                    7
# ОР50                                   6
# Швеллер 40У                            4
# Шар заг d шара 100 мм 2 гр.            2
# Швеллер 40У (12 категория)             1
# Name: ПРОФИЛЬ, dtype: int64

# %%
df['МАРКА'].value_counts()
# Out:
# Э76ХФ     4432
# Э90ХАФ    1346
# Э73Ф       223
# Э76Ф        85
# R350HT      53
# 900А        52
# Э76ХАФ      50
# Э76         49
# Ш2.2        44
# G2HH        34
# R260        33
# Ш2Л         31
# НХ           7
# С345         2
# 09Г2С        1
# С255         1
# С355         1
# Name: МАРКА, dtype: int64

# %% [markdown]
# Удаляем колонки 'nplv', 'DT', 'ПРОФИЛЬ', 'произв количество обработок'

# %%
df.drop(['nplv', 'DT', 'ПРОФИЛЬ', 'произв количество обработок'], axis=1, inplace=True)
df.shape
# Out:
# (6444, 80)

# %%
num_of_na = df.isna().sum(axis=0)

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(num_of_na / df.shape[0] * 100)
# Out:
# МАРКА                              0.000000
# t вып-обр                          0.000000
# t обработка                        0.062073
# t под током                        0.062073
# t продувка                         0.000000
# ПСН гр.                           18.544382
# чист расход C                      0.139665
# чист расход Cr                     8.705773
# чист расход Mn                     0.201738
# чист расход Si                     0.201738
# чист расход V                      4.127871
# температура первая                 0.124146
# температура последняя              0.124146
# Ar (интенс.)                       0.279330
# N2 (интенс.)                      78.445065
# эл. энергия (интенс.)              0.062073
# произв жидкая сталь                0.000000
# произв  количество плавок          0.000000
# произв количество плавок (цел)     0.000000
# расход газ Ar                      0.279330
# расход газ  N2                    78.445065
# расход C пров.                    88.764742
# сыпуч известь РП                  25.977654
# сыпуч кварцит                     99.798262
# сыпуч кокс пыль УСТК               0.341403
# сыпуч  кокс. мелочь (сух.)        99.891372
# сыпуч  кокс. мелочь КМ1            2.126009
# сыпуч  шпат плав.                  8.286778
# ферспл CaC2                        3.103662
# ферспл FeMo                       99.487896
# ферспл FeSi-75                    99.922408
# ферспл FeV азот.                  94.056487
# ферспл  FeV-80                     4.112353
# ферспл  Mn5Si65Al0.5               0.682806
# ферспл  Ni H1 пласт.              98.727498
# ферспл SiMn18                      0.713842
# ферспл  ферванит                  84.217877
# ферспл  фх850А                     8.705773
# эл. энергия                        0.062073
# химсталь первый Al_1               0.000000
# химсталь первый C_1                0.000000
# химсталь первый Cr_1               0.000000
# химсталь первый Cu_1               0.000000
# химсталь первый Mn_1               0.000000
# химсталь первый Mo_1               0.015518
# химсталь первый N_1                0.015518
# химсталь первый Ni_1               0.000000
# химсталь первый P_1                0.000000
# химсталь первый S_1                0.000000
# химсталь первый Si_1               0.000000
# химсталь первый Ti_1               0.000000
# химсталь первый V_1                0.000000
# химсталь последний Al              0.000000
# химсталь последний C               0.000000
# химсталь последний Ca              3.507138
# химсталь последний Cr              0.000000
# химсталь последний Cu              0.000000
# химсталь последний Mn              0.000000
# химсталь последний Mo              0.000000
# химсталь последний N               0.031037
# химсталь последний Ni              0.000000
# химсталь последний P               0.000000
# химсталь последний S               0.000000
# химсталь последний Si              0.000000
# химсталь последний Ti              0.000000
# химсталь последний V               0.000000
# химшлак первый Al2O3_1            26.412166
# химшлак первый CaO_1               0.000000
# химшлак первый FeO_1               0.000000
# химшлак первый MgO_1               0.015518
# химшлак первый MnO_1               0.000000
# химшлак первый R_1                 0.000000
# химшлак первый SiO2_1             26.412166
# химшлак последний Al2O3           26.412166
# химшлак последний CaO              0.000000
# химшлак последний FeO              0.000000
# химшлак последний MgO              0.015518
# химшлак последний MnO              0.000000
# химшлак последний R                0.000000
# химшлак последний SiO2            26.412166
# dtype: float64

# %% [markdown]
# В некоторых столбцах таргета осталось одинаковое количество пропусков, проверим везде ли они пропадут

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(df[df['химшлак последний SiO2'].notna()].isna().sum(axis=0))
# Out:
# МАРКА                                0
# t вып-обр                            0
# t обработка                          3
# t под током                          2
# t продувка                           0
# ПСН гр.                            948
# чист расход C                        6
# чист расход Cr                     418
# чист расход Mn                       8
# чист расход Si                       8
# чист расход V                      175
# температура первая                   6
# температура последняя                6
# Ar (интенс.)                         7
# N2 (интенс.)                      3716
# эл. энергия (интенс.)                2
# произв жидкая сталь                  0
# произв  количество плавок            0
# произв количество плавок (цел)       0
# расход газ Ar                        7
# расход газ  N2                    3716
# расход C пров.                    4151
# сыпуч известь РП                   978
# сыпуч кварцит                     4737
# сыпуч кокс пыль УСТК                10
# сыпуч  кокс. мелочь (сух.)        4742
# сыпуч  кокс. мелочь КМ1             81
# сыпуч  шпат плав.                  467
# ферспл CaC2                        174
# ферспл FeMo                       4741
# ферспл FeSi-75                    4737
# ферспл FeV азот.                  4588
# ферспл  FeV-80                     174
# ферспл  Mn5Si65Al0.5                29
# ферспл  Ni H1 пласт.              4706
# ферспл SiMn18                       35
# ферспл  ферванит                  3861
# ферспл  фх850А                     418
# эл. энергия                          2
# химсталь первый Al_1                 0
# химсталь первый C_1                  0
# химсталь первый Cr_1                 0
# химсталь первый Cu_1                 0
# химсталь первый Mn_1                 0
# химсталь первый Mo_1                 1
# химсталь первый N_1                  1
# химсталь первый Ni_1                 0
# химсталь первый P_1                  0
# химсталь первый S_1                  0
# химсталь первый Si_1                 0
# химсталь первый Ti_1                 0
# химсталь первый V_1                  0
# химсталь последний Al                0
# химсталь последний C                 0
# химсталь последний Ca              166
# химсталь последний Cr                0
# химсталь последний Cu                0
# химсталь последний Mn                0
# химсталь последний Mo                0
# химсталь последний N                 2
# химсталь последний Ni                0
# химсталь последний P                 0
# химсталь последний S                 0
# химсталь последний Si                0
# химсталь последний Ti                0
# химсталь последний V                 0
# химшлак первый Al2O3_1               0
# химшлак первый CaO_1                 0
# химшлак первый FeO_1                 0
# химшлак первый MgO_1                 1
# химшлак первый MnO_1                 0
# химшлак первый R_1                   0
# химшлак первый SiO2_1                0
# химшлак последний Al2O3              0
# химшлак последний CaO                0
# химшлак последний FeO                0
# химшлак последний MgO                1
# химшлак последний MnO                0
# химшлак последний R                  0
# химшлак последний SiO2               0
# dtype: int64

# %% [markdown]
# да, теперь таргет почти чист, остался только один пропуск, скипнем его тоже

# %%
df = df[df['химшлак последний SiO2'].notna()]

# %%
df = df[df['химшлак последний MgO'].notna()]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4741 entries, 463 to 7040
# Data columns (total 80 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   МАРКА                           4741 non-null   object
#  1   t вып-обр                       4741 non-null   float64
#  2   t обработка                     4738 non-null   float64
#  3   t под током                     4739 non-null   float64
#  4   t продувка                      4741 non-null   float64
#  5   ПСН гр.                         3793 non-null   float64
#  6   чист расход C                   4735 non-null   float64
#  7   чист расход Cr                  4323 non-null   float64
#  8   чист расход Mn                  4733 non-null   float64
#  9   чист расход Si                  4733 non-null   float64
#  10  чист расход V                   4566 non-null   float64
#  11  температура первая              4735 non-null   float64
#  12  температура последняя           4735 non-null   float64
#  13  Ar (интенс.)                    4734 non-null   float64
#  14  N2 (интенс.)                    1026 non-null   float64
#  15  эл. энергия (интенс.)           4739 non-null   float64
#  16  произв жидкая сталь             4741 non-null   float64
#  17  произв  количество плавок       4741 non-null   float64
#  18  произв количество плавок (цел)  4741 non-null   float64
#  19  расход газ Ar                   4734 non-null   float64
#  20  расход газ  N2                  1026 non-null   float64
#  21  расход C пров.                  591 non-null    float64
#  22  сыпуч известь РП                3763 non-null   float64
#  23  сыпуч кварцит                   5 non-null      float64
#  24  сыпуч кокс пыль УСТК            4731 non-null   float64
#  25  сыпуч  кокс. мелочь (сух.)      0 non-null      float64
#  26  сыпуч  кокс. мелочь КМ1         4660 non-null   float64
#  27  сыпуч  шпат плав.               4274 non-null   float64
#  28  ферспл CaC2                     4567 non-null   float64
#  29  ферспл FeMo                     1 non-null      float64
#  30  ферспл FeSi-75                  5 non-null      float64
#  31  ферспл FeV азот.                154 non-null    float64
#  32  ферспл  FeV-80                  4567 non-null   float64
#  33  ферспл  Mn5Si65Al0.5            4712 non-null   float64
#  34  ферспл  Ni H1 пласт.            36 non-null     float64
#  35  ферспл SiMn18                   4706 non-null   float64
#  36  ферспл  ферванит                881 non-null    float64
#  37  ферспл  фх850А                  4323 non-null   float64
#  38  эл. энергия                     4739 non-null   float64
#  39  химсталь первый Al_1            4741 non-null   float64
#  40  химсталь первый C_1             4741 non-null   float64
#  41  химсталь первый Cr_1            4741 non-null   float64
#  42  химсталь первый Cu_1            4741 non-null   float64
#  43  химсталь первый Mn_1            4741 non-null   float64
#  44  химсталь первый Mo_1            4740 non-null   float64
#  45  химсталь первый N_1             4740 non-null   float64
#  46  химсталь первый Ni_1            4741 non-null   float64
#  47  химсталь первый P_1             4741 non-null   float64
#  48  химсталь первый S_1             4741 non-null   float64
#  49  химсталь первый Si_1            4741 non-null   float64
#  50  химсталь первый Ti_1            4741 non-null   float64
#  51  химсталь первый V_1             4741 non-null   float64
#  52  химсталь последний Al           4741 non-null   float64
#  53  химсталь последний C            4741 non-null   float64
#  54  химсталь последний Ca           4575 non-null   float64
#  55  химсталь последний Cr           4741 non-null   float64
#  56  химсталь последний Cu           4741 non-null   float64
#  57  химсталь последний Mn           4741 non-null   float64
#  58  химсталь последний Mo           4741 non-null   float64
#  59  химсталь последний N            4739 non-null   float64
#  60  химсталь последний Ni           4741 non-null   float64
#  61  химсталь последний P            4741 non-null   float64
#  62  химсталь последний S            4741 non-null   float64
#  63  химсталь последний Si           4741 non-null   float64
#  64  химсталь последний Ti           4741 non-null   float64
#  65  химсталь последний V            4741 non-null   float64
#  66  химшлак первый Al2O3_1          4741 non-null   float64
#  67  химшлак первый CaO_1            4741 non-null   float64
#  68  химшлак первый FeO_1            4741 non-null   float64
#  69  химшлак первый MgO_1            4741 non-null   float64
#  70  химшлак первый MnO_1            4741 non-null   float64
#  71  химшлак первый R_1              4741 non-null   float64
#  72  химшлак первый SiO2_1           4741 non-null   float64
#  73  химшлак последний Al2O3         4741 non-null   float64
#  74  химшлак последний CaO           4741 non-null   float64
#  75  химшлак последний FeO           4741 non-null   float64
#  76  химшлак последний MgO           4741 non-null   float64
#  77  химшлак последний MnO           4741 non-null   float64
#  78  химшлак последний R             4741 non-null   float64
#  79  химшлак последний SiO2          4741 non-null   float64
# dtypes: float64(79), object(1)
# memory usage: 2.9+ MB

# %% [markdown]
# Выкинем фичи с огромным количеством пропусков

# %%
many_nans = ['сыпуч кварцит', 'расход C пров.', 'сыпуч  кокс. мелочь (сух.)', 'ферспл FeMo', 'ферспл FeSi-75',
'ферспл FeV азот.', 'ферспл  Ni H1 пласт.']
df.drop(many_nans, axis=1, inplace=True)

# %%
df.shape
# Out:
# (4741, 73)

# %% [markdown]
# Избавились от 11 фичей. Посмотрим на матрицу ковариации и найдём сильно кореллирующие переменные

# %%
corr_matrix = df.corr('spearman')
diag_mask = np.triu(corr_matrix)
fig, ax = plt.subplots(figsize=(10, 8))
ax = sns.heatmap(corr_matrix, mask=diag_mask);

# %%
df[['произв  количество плавок', 'произв количество плавок (цел)']].describe()
# Out:
#        произв  количество плавок  произв количество плавок (цел)
# count                     4741.0                          4741.0
# mean                         1.0                             1.0
# std                          0.0                             0.0
# min                          1.0                             1.0
# 25%                          1.0                             1.0
# 50%                          1.0                             1.0
# 75%                          1.0                             1.0
# max                          1.0                             1.0

# %%
df.drop(['произв  количество плавок', 'произв количество плавок (цел)'], axis=1, inplace=True); # всегда 1

# %%
corr_matrix = df.corr('spearman')
diag_mask = np.triu(corr_matrix)
fig, ax = plt.subplots(figsize=(10, 8))
ax = sns.heatmap(corr_matrix, mask=diag_mask);

# %% [markdown]
# сильно коррелирующие пары

# %%
corr_matrix = corr_matrix[np.abs(corr_matrix) > 0.75]
diag_mask = np.triu(corr_matrix)
fig, ax = plt.subplots(figsize=(10, 8))
ax = sns.heatmap(corr_matrix, mask=diag_mask);

# %% [markdown]
# 15 пар, посмотрим на их зависимости друг от друга

# %%
good_corr = (np.abs(corr_matrix) > 0.75).reset_index().melt(id_vars='index').query('value == True')
good_corr = good_corr[~(good_corr['index'] == good_corr['variable'])]
good_corr = good_corr.reset_index().drop(['level_0'], axis=1)

# %%
col_list = []
counter = 0
for i, val in good_corr.iterrows():
    if set([val[0], val[1]]) not in col_list:
        counter += 1
        print(counter)
        col_list.append(set([val[0], val[1]]))
        print(val[0])
        print('Ненулевые значения:', df[val[0]].notna().sum(), '/', df.shape[0])
        print()
        print(val[1])
        print('Ненулевые значения:', df[val[1]].notna().sum(), '/', df.shape[0])
        sns.displot(x=df[val[0]], y=df[val[1]]);
        plt.title(f'{df[[val[0], val[1]]].corr().iloc[0, 1]:.3f}')
        plt.show();
        print('________________________')
# Out:
# 1
# t продувка
# Ненулевые значения: 4741 / 4741
#
# t обработка
# Ненулевые значения: 4738 / 4741
# ________________________
# 2
# эл. энергия
# Ненулевые значения: 4739 / 4741
#
# t под током
# Ненулевые значения: 4739 / 4741
# ________________________
# 3
# сыпуч  кокс. мелочь КМ1
# Ненулевые значения: 4660 / 4741
#
# чист расход C
# Ненулевые значения: 4735 / 4741
# ________________________
# 4
# химсталь первый C_1
# Ненулевые значения: 4741 / 4741
#
# чист расход C
# Ненулевые значения: 4735 / 4741
# ________________________
# 5
# ферспл  фх850А
# Ненулевые значения: 4323 / 4741
#
# чист расход Cr
# Ненулевые значения: 4323 / 4741
# ________________________
# 6
# ферспл SiMn18
# Ненулевые значения: 4706 / 4741
#
# чист расход Mn
# Ненулевые значения: 4733 / 4741
# ________________________
# 7
# химсталь первый Mn_1
# Ненулевые значения: 4741 / 4741
#
# чист расход Mn
# Ненулевые значения: 4733 / 4741
# ________________________
# 8
# ферспл  Mn5Si65Al0.5
# Ненулевые значения: 4712 / 4741
#
# чист расход Si
# Ненулевые значения: 4733 / 4741
# ________________________
# 9
# ферспл  FeV-80
# Ненулевые значения: 4567 / 4741
#
# чист расход V
# Ненулевые значения: 4566 / 4741
# ________________________
# 10
# химсталь первый Mn_1
# Ненулевые значения: 4741 / 4741
#
# ферспл SiMn18
# Ненулевые значения: 4706 / 4741
# ________________________
# 11
# химсталь последний Cu
# Ненулевые значения: 4741 / 4741
#
# химсталь первый Cu_1
# Ненулевые значения: 4741 / 4741
# ________________________
# 12
# химсталь последний Mo
# Ненулевые значения: 4741 / 4741
#
# химсталь первый Mo_1
# Ненулевые значения: 4740 / 4741
# ________________________
# 13
# химсталь последний Ni
# Ненулевые значения: 4741 / 4741
#
# химсталь первый Ni_1
# Ненулевые значения: 4741 / 4741
# ________________________
# 14
# химсталь последний P
# Ненулевые значения: 4741 / 4741
#
# химсталь первый P_1
# Ненулевые значения: 4741 / 4741
# ________________________
# 15
# химшлак последний SiO2
# Ненулевые значения: 4741 / 4741
#
# химшлак последний R
# Ненулевые значения: 4741 / 4741
# ________________________

# %% [markdown]
# Возьмём все пары с корреляцией 0.99..
# 1
# t продувка
# Ненулевые значения: 4741 / 4741
# t обработка
# Ненулевые значения: 4738 / 4741
#
# удалим 't обработка'
#
# ---
# 5
# ферспл  фх850А
# Ненулевые значения: 4323 / 4741
#
# чист расход Cr
# Ненулевые значения: 4323 / 4741
#
# удалим 'ферспл  фх850А'
#
# ---
# 6
# ферспл SiMn18
# Ненулевые значения: 4706 / 4741
#
# чист расход Mn
# Ненулевые значения: 4733 / 4741
#
# удалим 'ферспл SiMn18'
#
# ---
#
# 9
# ферспл  FeV-80
# Ненулевые значения: 4567 / 4741
#
# чист расход V
# Ненулевые значения: 4566 / 4741
#
# тут не уверен (см график), нужно посмотреть на них внимательнее
#
# ---
# 11
# химсталь последний Cu
# Ненулевые значения: 4741 / 4741
#
# химсталь первый Cu_1
# Ненулевые значения: 4741 / 4741
#
# удалим 'химсталь первый Cu_1'
#
# ---
#
# Точно минус 4 столбца

# %%
drop_list = ['t обработка', 'ферспл  фх850А', 'ферспл SiMn18', 'химсталь первый Cu_1']
df.drop(drop_list, axis=1, inplace=True)
df.shape
# Out:
# (4741, 67)

# %% [markdown]
# смотрим на 'ферспл  FeV-80' и 'чист расход V'

# %%
sns.boxplot(df['ферспл  FeV-80']);

# %%
sns.boxplot(df['чист расход V'])
# Out:
# <AxesSubplot:xlabel='чист расход V'>

# %%
df[['ферспл  FeV-80', 'чист расход V']].hist()
# Out:
# array([[<AxesSubplot:title={'center':'ферспл  FeV-80'}>,
#         <AxesSubplot:title={'center':'чист расход V'}>]], dtype=object)

# %% [markdown]
# заполним оставшиеся пропуски медианой

# %%
df = df.fillna(df.median())

# %% [markdown]
# Удалим выбросы

# %%
from sklearn.ensemble import IsolationForest

out_forest = IsolationForest()
out_forest.fit(df.iloc[:, 1:])
outlier_predicted = out_forest.predict(df.iloc[:, 1:])
df = df[outlier_predicted == 1].copy()
df.shape
# Out:
# (4576, 67)

# %% [markdown]
# выделим таргет и посмотрим на его корреляцию

# %%
target = [col for col in df.columns if col.startswith('химшлак последний')]

# %%
corr_matrix = df[target].corr()
diag_mask = np.triu(corr_matrix)
fig, ax = plt.subplots(figsize=(10, 8))
ax = sns.heatmap(corr_matrix, mask=diag_mask);

# %%
sns.pairplot(df[target])

# %%
df.shape
# Out:
# (4576, 67)

# %%
df['МАРКА'].value_counts()
# Out:
# Э76ХФ     3247
# Э90ХАФ     959
# Э73Ф       154
# Э76Ф        66
# Э76         36
# Э76ХАФ      32
# R260        27
# R350HT      21
# Ш2.2        17
# Ш2Л         10
# НХ           7
# Name: МАРКА, dtype: int64

# %% [markdown]
# Сгрупируем стали в 3 класса

# %%
other_steels = list(df['МАРКА'].value_counts()[2:].index)
other_steels
# Out:
# ['Э73Ф', 'Э76Ф', 'Э76', 'Э76ХАФ', 'R260', 'R350HT', 'Ш2.2', 'Ш2Л', 'НХ']

# %%
steel_map = {steel:'Другие' for steel in other_steels}
steel_map
# Out:
# {'Э73Ф': 'Другие',
#  'Э76Ф': 'Другие',
#  'Э76': 'Другие',
#  'Э76ХАФ': 'Другие',
#  'R260': 'Другие',
#  'R350HT': 'Другие',
#  'Ш2.2': 'Другие',
#  'Ш2Л': 'Другие',
#  'НХ': 'Другие'}

# %%
df['МАРКА'].replace(steel_map).value_counts()
# Out:
# Э76ХФ     3247
# Э90ХАФ     959
# Другие     370
# Name: МАРКА, dtype: int64

# %%
df['МАРКА'] = df['МАРКА'].replace(steel_map)
df['МАРКА']
# Out:
# 589      Э76ХФ
# 818     Э90ХАФ
# 1029    Другие
# 1036    Другие
# 1345     Э76ХФ
#          ...
# 7036    Э90ХАФ
# 7037    Э90ХАФ
# 7038    Э90ХАФ
# 7039    Э90ХАФ
# 7040    Э90ХАФ
# Name: МАРКА, Length: 4576, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4576 entries, 589 to 7040
# Data columns (total 67 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   МАРКА                    4576 non-null   object
#  1   t вып-обр                4576 non-null   float64
#  2   t под током              4576 non-null   float64
#  3   t продувка               4576 non-null   float64
#  4   ПСН гр.                  4576 non-null   float64
#  5   чист расход C            4576 non-null   float64
#  6   чист расход Cr           4576 non-null   float64
#  7   чист расход Mn           4576 non-null   float64
#  8   чист расход Si           4576 non-null   float64
#  9   чист расход V            4576 non-null   float64
#  10  температура первая       4576 non-null   float64
#  11  температура последняя    4576 non-null   float64
#  12  Ar (интенс.)             4576 non-null   float64
#  13  N2 (интенс.)             4576 non-null   float64
#  14  эл. энергия (интенс.)    4576 non-null   float64
#  15  произв жидкая сталь      4576 non-null   float64
#  16  расход газ Ar            4576 non-null   float64
#  17  расход газ  N2           4576 non-null   float64
#  18  сыпуч известь РП         4576 non-null   float64
#  19  сыпуч кокс пыль УСТК     4576 non-null   float64
#  20  сыпуч  кокс. мелочь КМ1  4576 non-null   float64
#  21  сыпуч  шпат плав.        4576 non-null   float64
#  22  ферспл CaC2              4576 non-null   float64
#  23  ферспл  FeV-80           4576 non-null   float64
#  24  ферспл  Mn5Si65Al0.5     4576 non-null   float64
#  25  ферспл  ферванит         4576 non-null   float64
#  26  эл. энергия              4576 non-null   float64
#  27  химсталь первый Al_1     4576 non-null   float64
#  28  химсталь первый C_1      4576 non-null   float64
#  29  химсталь первый Cr_1     4576 non-null   float64
#  30  химсталь первый Mn_1     4576 non-null   float64
#  31  химсталь первый Mo_1     4576 non-null   float64
#  32  химсталь первый N_1      4576 non-null   float64
#  33  химсталь первый Ni_1     4576 non-null   float64
#  34  химсталь первый P_1      4576 non-null   float64
#  35  химсталь первый S_1      4576 non-null   float64
#  36  химсталь первый Si_1     4576 non-null   float64
#  37  химсталь первый Ti_1     4576 non-null   float64
#  38  химсталь первый V_1      4576 non-null   float64
#  39  химсталь последний Al    4576 non-null   float64
#  40  химсталь последний C     4576 non-null   float64
#  41  химсталь последний Ca    4576 non-null   float64
#  42  химсталь последний Cr    4576 non-null   float64
#  43  химсталь последний Cu    4576 non-null   float64
#  44  химсталь последний Mn    4576 non-null   float64
#  45  химсталь последний Mo    4576 non-null   float64
#  46  химсталь последний N     4576 non-null   float64
#  47  химсталь последний Ni    4576 non-null   float64
#  48  химсталь последний P     4576 non-null   float64
#  49  химсталь последний S     4576 non-null   float64
#  50  химсталь последний Si    4576 non-null   float64
#  51  химсталь последний Ti    4576 non-null   float64
#  52  химсталь последний V     4576 non-null   float64
#  53  химшлак первый Al2O3_1   4576 non-null   float64
#  54  химшлак первый CaO_1     4576 non-null   float64
#  55  химшлак первый FeO_1     4576 non-null   float64
#  56  химшлак первый MgO_1     4576 non-null   float64
#  57  химшлак первый MnO_1     4576 non-null   float64
#  58  химшлак первый R_1       4576 non-null   float64
#  59  химшлак первый SiO2_1    4576 non-null   float64
#  60  химшлак последний Al2O3  4576 non-null   float64
#  61  химшлак последний CaO    4576 non-null   float64
#  62  химшлак последний FeO    4576 non-null   float64
#  63  химшлак последний MgO    4576 non-null   float64
#  64  химшлак последний MnO    4576 non-null   float64
#  65  химшлак последний R      4576 non-null   float64
#  66  химшлак последний SiO2   4576 non-null   float64
# dtypes: float64(66), object(1)
# memory usage: 2.4+ MB

# %%
df.shape
# Out:
# (4576, 67)

# %%
(df.columns ^ target).shape
# Out:
# (60,)

# %% [markdown]
# ### Выводы
#
# 1. Удалены колонки 'nplv', 'DT', 'ПРОФИЛЬ', 'произв количество обработок' как нерелевантные либо содержащие неуникальные значения.
# 2. Удалены малоинформативные полупустые столбцы (11).
# 3. Строки с большим количеством пропусков в целевых переменных были удалены.
# 4. Построена матрица корреляции и рассмотрены столбцы с высокой созависимостью. Удалено 3 линейно зависимые переменные.
# 5. Оставшиеся пропуски заполнены медианными значениями.
# 6. Марки стали объеденены в 3 класса.
# 6. Выбросы были удалены с помощью IsolationForest
# 7. В итоге остались 4576 строк из исходных 7041 и 67 переменных из исходных 84 (включая 7 целевых)

# %%
# сохраним очищенные данные
df.to_csv('clean_data.csv')
