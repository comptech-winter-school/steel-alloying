# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()

# %% [markdown]
# # Exploratory data analysis

# %% [markdown]
# Загрузим датасет, настроим pandas на отображение всех колонок

# %%
dataset = pd.read_csv("dataset.csv", sep=';', decimal=',')

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# %% [markdown]
# Первые записи:

# %%
dataset.head()
# Out:
#    Unnamed: 0         nplv                   DT  МАРКА ПРОФИЛЬ  t вып-обр  \
# 0           0  г6837?3<87?  2070-06-21 00:14:00  Э76ХФ     Р65       29.0
# 1           1  г683863<886  2070-06-21 01:07:00  Э76ХФ     Р65       26.0
# 2           2  г683863<887  2070-06-21 02:00:00  Э76ХФ     Р65       24.0
# 3           3  г683863<888  2070-06-21 02:58:00  Э76ХФ     Р65       17.0
# 4           4  г683863<889  2070-06-21 03:50:00  Э76ХФ     Р65       20.0
#
#    t обработка  t под током  t продувка  ПСН гр.  чист расход C  \
# 0    45.366667    24.400000   41.033333      NaN       0.456460
# 1    44.066667    13.866667   44.066667      NaN       0.359285
# 2    43.350000    17.950000   43.350000      NaN       0.331665
# 3    46.183333    19.816667   46.183333      NaN       0.377945
# 4    48.500000    17.033333   48.500000      NaN       0.389875
#
#    чист расход Cr  чист расход Mn  чист расход Si  чист расход V  \
# 0        0.059572        0.117446        0.104762       0.040938
# ...

# %% [markdown]
# Сразу выбрасывается признак "Unnamed: 0" (дублирует индекс):

# %%
dataset.drop("Unnamed: 0", axis=1, inplace=True)

# %%
dataset.shape
# Out:
# (7041, 84)

# %% [markdown]
# Датасет содержит 7041 объект.
# Объект содержит 84 признака.

# %% [markdown]
# Описание признаков:

# %%
dataset.describe(include='all')
# Out:
#                nplv                   DT  МАРКА ПРОФИЛЬ    t вып-обр  \
# count          7041                 7041   7041    7041  6444.000000
# unique         7041                 7041     18      18          NaN
# top     г683863887>  2070-09-20 18:00:00  Э76ХФ     Р65          NaN
# freq              1                    1   4953    6427          NaN
# mean            NaN                  NaN    NaN     NaN    26.492241
# std             NaN                  NaN    NaN     NaN    14.842045
# min             NaN                  NaN    NaN     NaN    -1.000000
# 25%             NaN                  NaN    NaN     NaN    14.000000
# 50%             NaN                  NaN    NaN     NaN    25.000000
# 75%             NaN                  NaN    NaN     NaN    37.000000
# max             NaN                  NaN    NaN     NaN    98.000000
#
#         t обработка  t под током   t продувка      ПСН гр.  чист расход C  \
# ...

# %% [markdown]
# ### Количество пропусков и типы

# %%
def make_description(df):
    description = pd.concat([df.isna().sum(), df.dtypes], axis=1)
    description.rename(columns={0: "num of NaN", 1: "dtypes"}, inplace=True)
    return description

# %%
make_description(dataset)
# Out:
#                                 num of NaN   dtypes
# nplv                                     0   object
# DT                                       0   object
# МАРКА                                    0   object
# ПРОФИЛЬ                                  0   object
# t вып-обр                              597  float64
# t обработка                            601  float64
# t под током                            601  float64
# t продувка                             597  float64
# ПСН гр.                               1792  float64
# чист расход C                          606  float64
# чист расход Cr                        1158  float64
# чист расход Mn                         610  float64
# чист расход Si                         610  float64
# чист расход V                          863  float64
# температура первая                     605  float64
# температура последняя                  605  float64
# Ar (интенс.)                           615  float64
# ...

# %%
dataset.columns
# Out:
# Index(['nplv', 'DT', 'МАРКА', 'ПРОФИЛЬ', 't вып-обр', 't обработка',
#        't под током', 't продувка', 'ПСН гр.', 'чист расход C',
#        'чист расход Cr', 'чист расход Mn', 'чист расход Si', 'чист расход V',
#        'температура первая', 'температура последняя', 'Ar (интенс.)',
#        'N2 (интенс.)', 'эл. энергия (интенс.)', 'произв жидкая сталь',
#        'произв количество обработок', 'произв  количество плавок',
#        'произв количество плавок (цел)', 'расход газ Ar', 'расход газ  N2',
#        'расход C пров.', 'сыпуч известь РП', 'сыпуч кварцит',
#        'сыпуч кокс пыль УСТК', 'сыпуч  кокс. мелочь (сух.)',
#        'сыпуч  кокс. мелочь КМ1', 'сыпуч  шпат плав.', 'ферспл CaC2',
#        'ферспл FeMo', 'ферспл FeSi-75', 'ферспл FeV азот.', 'ферспл  FeV-80',
#        'ферспл  Mn5Si65Al0.5', 'ферспл  Ni H1 пласт.', 'ферспл SiMn18',
#        'ферспл  ферванит', 'ферспл  фх850А', 'эл. энергия',
# ...

# %% [markdown]
# ## Категориальные признаки
#
# Категориальными типами являются:
# - **nplv** - номер плавки, не имеет смысла
# - **DT** - дата и время плавки
# - **МАРКА** - марка стали (?)
# - **ПРОФИЛЬ** - профиль стали (?)

# %%
categorical_features = ["nplv", "DT", "МАРКА", "ПРОФИЛЬ"]

dataset[categorical_features].head()
# Out:
#           nplv                   DT  МАРКА ПРОФИЛЬ
# 0  г6837?3<87?  2070-06-21 00:14:00  Э76ХФ     Р65
# 1  г683863<886  2070-06-21 01:07:00  Э76ХФ     Р65
# 2  г683863<887  2070-06-21 02:00:00  Э76ХФ     Р65
# 3  г683863<888  2070-06-21 02:58:00  Э76ХФ     Р65
# 4  г683863<889  2070-06-21 03:50:00  Э76ХФ     Р65

# %%
print("Количество всех пропущенных категориальных значений: {}".format(dataset[categorical_features].isna().sum().sum()))
# Out:
# Количество всех пропущенных категориальных значений: 0

# %% [markdown]
# #### МАРКА

# %%
print("Количество уникальных значений: {}".format(dataset["МАРКА"].nunique()))
print("\nЧастота встречаемости каждого из значений:")
print(dataset["МАРКА"].value_counts())
# Out:
# Количество уникальных значений: 18
#
# Частота встречаемости каждого из значений:
# Э76ХФ     4953
# Э90ХАФ    1384
# Э73Ф       227
# Э76Ф        86
# Ш2.2        59
# Э76         56
# R350HT      54
# 900А        54
# Э76ХАФ      50
# R260        35
# G2HH        34
# Ш2Л         31
# НХ           7
# 09Г2С        4
# С345         3
# С255         2
# Ст3сп        1
# С355         1
# Name: МАРКА, dtype: int64

# %% [markdown]
# #### ПРОФИЛЬ

# %%
print("Количество уникальных значений: {}".format(dataset["ПРОФИЛЬ"].nunique()))
print("\nЧастота встречаемости каждого из значений:")
print(dataset["ПРОФИЛЬ"].value_counts())
# Out:
# Количество уникальных значений: 18
#
# Частота встречаемости каждого из значений:
# Р65                                 6427
# ОР65                                 221
# 60E1                                  95
# Шар заг d шара 80-100 мм 2,3 гр.      59
# Рельсы трамвайные                     56
# UIC54                                 54
# Р50                                   44
# 136 RE                                17
# Шар заг d шара 80-100 мм 4 гр.        17
# Шары мелющие d 80-100 мм              14
# 54E1                                  10
# НЕТ                                    7
# ОР50                                   6
# Швеллер 40У                            6
# Швеллер 40У (12 категория)             4
# Шар заг d шара 100 мм 2 гр.            2
# 60E2                                   1
# НЛЗ 300х365                            1
# Name: ПРОФИЛЬ, dtype: int64

# %% [markdown]
# ## Вещественные признаки
#
# Все остальные 80 признаков имеют вещественный тип данных

# %%
numerical_features = ['t вып-обр', 't обработка',
       't под током', 't продувка', 'ПСН гр.', 'чист расход C',
       'чист расход Cr', 'чист расход Mn', 'чист расход Si', 'чист расход V',
       'температура первая', 'температура последняя', 'Ar (интенс.)',
       'N2 (интенс.)', 'эл. энергия (интенс.)', 'произв жидкая сталь',
       'произв количество обработок', 'произв  количество плавок',
       'произв количество плавок (цел)', 'расход газ Ar', 'расход газ  N2',
       'расход C пров.', 'сыпуч известь РП', 'сыпуч кварцит',
       'сыпуч кокс пыль УСТК', 'сыпуч  кокс. мелочь (сух.)',
       'сыпуч  кокс. мелочь КМ1', 'сыпуч  шпат плав.', 'ферспл CaC2',
       'ферспл FeMo', 'ферспл FeSi-75', 'ферспл FeV азот.', 'ферспл  FeV-80',
       'ферспл  Mn5Si65Al0.5', 'ферспл  Ni H1 пласт.', 'ферспл SiMn18',
       'ферспл  ферванит', 'ферспл  фх850А', 'эл. энергия',
       'химсталь первый Al_1', 'химсталь первый C_1', 'химсталь первый Cr_1',
       'химсталь первый Cu_1', 'химсталь первый Mn_1', 'химсталь первый Mo_1',
       'химсталь первый N_1', 'химсталь первый Ni_1', 'химсталь первый P_1',
       'химсталь первый S_1', 'химсталь первый Si_1', 'химсталь первый Ti_1',
       'химсталь первый V_1', 'химсталь последний Al', 'химсталь последний C',
       'химсталь последний Ca', 'химсталь последний Cr',
       'химсталь последний Cu', 'химсталь последний Mn',
       'химсталь последний Mo', 'химсталь последний N',
       'химсталь последний Ni', 'химсталь последний P', 'химсталь последний S',
       'химсталь последний Si', 'химсталь последний Ti',
       'химсталь последний V', 'химшлак первый Al2O3_1',
       'химшлак первый CaO_1', 'химшлак первый FeO_1', 'химшлак первый MgO_1',
       'химшлак первый MnO_1', 'химшлак первый R_1', 'химшлак первый SiO2_1',
       'химшлак последний Al2O3', 'химшлак последний CaO',
       'химшлак последний FeO', 'химшлак последний MgO',
       'химшлак последний MnO', 'химшлак последний R',
       'химшлак последний SiO2']

# %%
dataset[numerical_features].shape
# Out:
# (7041, 80)

# %% [markdown]
# #### Количество NaN значений у каждого признака

# %%
dataset[numerical_features].isna().sum()
# Out:
# t вып-обр                          597
# t обработка                        601
# t под током                        601
# t продувка                         597
# ПСН гр.                           1792
# чист расход C                      606
# чист расход Cr                    1158
# чист расход Mn                     610
# чист расход Si                     610
# чист расход V                      863
# температура первая                 605
# температура последняя              605
# Ar (интенс.)                       615
# N2 (интенс.)                      5652
# эл. энергия (интенс.)              601
# произв жидкая сталь                597
# произв количество обработок        597
# произв  количество плавок          597
# произв количество плавок (цел)     597
# расход газ Ar                      615
# расход газ  N2                    5652
# расход C пров.                    6317
# сыпуч известь РП                  2271
# сыпуч кварцит                     7028
# ...

# %% [markdown]
# #### Признаки, у которых более 33% значений NaN

# %%
features_with_lots_of_nan = []
for feature in numerical_features:
    num_of_nan = dataset[feature].isna().sum()
    if num_of_nan > dataset.shape[0] / 3:
        features_with_lots_of_nan.append(feature)
        
print(features_with_lots_of_nan)
# Out:
# ['N2 (интенс.)', 'расход газ  N2', 'расход C пров.', 'сыпуч кварцит', 'сыпуч  кокс. мелочь (сух.)', 'ферспл FeMo', 'ферспл FeSi-75', 'ферспл FeV азот.', 'ферспл  Ni H1 пласт.', 'ферспл  ферванит']

# %% [markdown]
# ### Распределения признаков

# %%
for feature in numerical_features:
    sns.displot(dataset[feature])
# Out:
# /Users/metra4ok/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:392: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
