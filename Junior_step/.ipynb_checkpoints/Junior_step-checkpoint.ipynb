# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

from scipy.stats import pearsonr
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import IsolationForest, RandomForestRegressor
from sklearn.feature_selection import SelectKBest, f_classif

import warnings
 
warnings.filterwarnings("ignore")

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
data = pd.read_table('steel_alloying.csv', sep=';', index_col=0, decimal=',')
data = data[data['t вып-обр'].notna()] # удаляем пустые строки
data.columns
data.head()
# Out:
#           nplv                   DT  МАРКА ПРОФИЛЬ  t вып-обр  t обработка  \
# 0  г6837?3<87?  2070-06-21 00:14:00  Э76ХФ     Р65       29.0    45.366667
# 1  г683863<886  2070-06-21 01:07:00  Э76ХФ     Р65       26.0    44.066667
# 2  г683863<887  2070-06-21 02:00:00  Э76ХФ     Р65       24.0    43.350000
# 3  г683863<888  2070-06-21 02:58:00  Э76ХФ     Р65       17.0    46.183333
# 4  г683863<889  2070-06-21 03:50:00  Э76ХФ     Р65       20.0    48.500000
#
#    t под током  t продувка  ПСН гр.  чист расход C  чист расход Cr  \
# 0    24.400000   41.033333      NaN       0.456460        0.059572
# 1    13.866667   44.066667      NaN       0.359285        0.083738
# 2    17.950000   43.350000      NaN       0.331665        0.081490
# 3    19.816667   46.183333      NaN       0.377945        0.133194
# 4    17.033333   48.500000      NaN       0.389875        0.105094
#
#    чист расход Mn  чист расход Si  чист расход V  температура первая  \
# 0        0.117446        0.104762       0.040938              1557.0
# 1        0.160923        0.110327       0.040083              1601.0
# 2        0.132332        0.139860       0.041622              1593.0
# 3        0.221605        0.165186       0.042050              1589.0
# 4        0.169459        0.143024       0.040967              1597.0
#
#    температура последняя  Ar (интенс.)  N2 (интенс.)  эл. энергия (интенс.)  \
# 0                 1580.0     13.606742           NaN           12809.016393
# 1                 1591.0      8.074721           NaN           12816.346154
# 2                 1586.0     13.801968           NaN           12511.420613
# 3                 1589.0     12.664959           NaN           12998.149706
# 4                 1592.0     10.298350           NaN           12987.475538
#
#    произв жидкая сталь  произв количество обработок  \
# 0                115.5                          1.0
# 1                111.6                          1.0
# 2                115.8                          1.0
# 3                116.3                          1.0
# 4                115.0                          1.0
#
#    произв  количество плавок  произв количество плавок (цел)  расход газ Ar  \
# 0                        1.0                             1.0         18.611
# 1                        1.0                             1.0         11.659
# 2                        1.0                             1.0         19.871
# 3                        1.0                             1.0         19.497
# 4                        1.0                             1.0         16.649
#
#    расход газ  N2  расход C пров.  сыпуч известь РП  сыпуч кварцит  \
# 0             NaN             NaN               NaN            NaN
# 1             NaN             NaN               NaN            NaN
# 2             NaN             NaN               NaN            NaN
# 3             NaN             NaN             0.077            NaN
# 4             NaN             NaN             0.082            NaN
#
#    сыпуч кокс пыль УСТК  сыпуч  кокс. мелочь (сух.)  сыпуч  кокс. мелочь КМ1  \
# 0                 0.170                         NaN                    0.401
# 1                 0.488                         NaN                      NaN
# 2                 0.050                         NaN                    0.346
# 3                 0.050                         NaN                    0.390
# 4                 0.050                         NaN                    0.412
#
#    сыпуч  шпат плав.  ферспл CaC2  ферспл FeMo  ферспл FeSi-75  \
# 0              0.123         0.02          NaN             NaN
# 1              0.094         0.02          NaN             NaN
# 2              0.061         0.02          NaN             NaN
# 3              0.059         0.02          NaN             NaN
# 4              0.035         0.02          NaN             NaN
#
#    ферспл FeV азот.  ферспл  FeV-80  ферспл  Mn5Si65Al0.5  \
# 0               NaN        0.051939                 0.112
# 1               NaN        0.050854                 0.102
# 2               NaN        0.052807                 0.160
# 3               NaN        0.053349                 0.161
# 4               NaN        0.051975                 0.149
#
#    ферспл  Ni H1 пласт.  ферспл SiMn18  ферспл  ферванит  ферспл  фх850А  \
# 0                   NaN          0.182               NaN           0.106
# 1                   NaN          0.251               NaN           0.149
# 2                   NaN          0.204               NaN           0.145
# 3                   NaN          0.345               NaN           0.237
# 4                   NaN          0.263               NaN           0.187
#
#    эл. энергия  химсталь первый Al_1  химсталь первый C_1  \
# 0       5209.0                 0.002                0.389
# 1       2962.0                 0.002                0.465
# 2       3743.0                 0.002                0.513
# 3       4293.0                 0.002                0.487
# 4       3687.0                 0.002                0.461
#
#    химсталь первый Cr_1  химсталь первый Cu_1  химсталь первый Mn_1  \
# 0                 0.368                 0.127                 0.682
# 1                 0.345                 0.112                 0.643
# 2                 0.351                 0.107                 0.674
# 3                 0.310                 0.105                 0.611
# 4                 0.334                 0.105                 0.652
#
#    химсталь первый Mo_1  химсталь первый N_1  химсталь первый Ni_1  \
# 0                 0.010                0.011                 0.086
# 1                 0.009                0.011                 0.080
# 2                 0.007                0.011                 0.078
# 3                 0.009                0.011                 0.070
# 4                 0.007                0.011                 0.080
#
#    химсталь первый P_1  химсталь первый S_1  химсталь первый Si_1  \
# 0                0.009                0.023                 0.459
# 1                0.007                0.023                 0.461
# 2                0.008                0.019                 0.455
# 3                0.006                0.020                 0.434
# 4                0.007                0.020                 0.447
#
#    химсталь первый Ti_1  химсталь первый V_1  химсталь последний Al  \
# 0                 0.002                0.002                  0.003
# 1                 0.002                0.002                  0.003
# 2                 0.002                0.002                  0.004
# 3                 0.001                0.001                  0.003
# 4                 0.001                0.002                  0.003
#
#    химсталь последний C  химсталь последний Ca  химсталь последний Cr  \
# 0                 0.756                 0.0001                  0.417
# 1                 0.774                 0.0003                  0.416
# 2                 0.770                 0.0009                  0.417
# 3                 0.767                 0.0002                  0.419
# 4                 0.784                 0.0003                  0.421
#
#    химсталь последний Cu  химсталь последний Mn  химсталь последний Mo  \
# 0                  0.126                  0.779                  0.009
# 1                  0.109                  0.767                  0.008
# 2                  0.108                  0.788                  0.006
# 3                  0.103                  0.795                  0.008
# 4                  0.105                  0.796                  0.006
#
#    химсталь последний N  химсталь последний Ni  химсталь последний P  \
# 0                 0.012                  0.086                 0.011
# 1                 0.013                  0.079                 0.008
# 2                 0.012                  0.078                 0.008
# 3                 0.013                  0.070                 0.007
# 4                 0.013                  0.081                 0.008
#
#    химсталь последний S  химсталь последний Si  химсталь последний Ti  \
# 0                 0.018                  0.559                  0.003
# 1                 0.021                  0.543                  0.003
# 2                 0.013                  0.568                  0.003
# 3                 0.014                  0.571                  0.003
# 4                 0.017                  0.568                  0.003
#
#    химсталь последний V  химшлак первый Al2O3_1  химшлак первый CaO_1  \
# 0                 0.037                     NaN                  63.7
# 1                 0.038                     NaN                  58.5
# 2                 0.038                     NaN                  58.0
# 3                 0.038                     NaN                  59.8
# 4                 0.037                     NaN                  59.6
#
#    химшлак первый FeO_1  химшлак первый MgO_1  химшлак первый MnO_1  \
# 0                   1.1                   3.7                  0.12
# 1                   0.8                   4.9                  0.14
# 2                   0.8                   8.6                  0.12
# 3                   0.4                   6.4                  0.11
# 4                   0.7                   4.7                  0.12
#
#    химшлак первый R_1  химшлак первый SiO2_1  химшлак последний Al2O3  \
# 0                 2.6                    NaN                      NaN
# 1                 2.2                    NaN                      NaN
# 2                 2.6                    NaN                      NaN
# 3                 2.4                    NaN                      NaN
# 4                 2.4                    NaN                      NaN
#
#    химшлак последний CaO  химшлак последний FeO  химшлак последний MgO  \
# 0                   53.4                    1.0                    5.8
# 1                   59.3                    0.6                    4.1
# 2                   57.2                    0.5                    8.1
# 3                   60.3                    0.5                    6.3
# 4                   60.3                    0.6                    4.5
#
#    химшлак последний MnO  химшлак последний R  химшлак последний SiO2
# 0                   0.15                  2.6                     NaN
# 1                   0.11                  2.3                     NaN
# 2                   0.13                  2.3                     NaN
# 3                   0.12                  2.6                     NaN
# 4                   0.09                  2.5                     NaN

# %%
data.drop(['nplv', 'DT', 'ПРОФИЛЬ', 'произв количество обработок'], axis=1, inplace=True)
data.drop(['произв  количество плавок', 'произв количество плавок (цел)'], axis=1, inplace=True)
data.drop(['ферспл  ферванит', 'расход C пров.', 'сыпуч кварцит', 'сыпуч кокс пыль УСТК', 'сыпуч  кокс. мелочь (сух.)', 'сыпуч  кокс. мелочь КМ1', 'ферспл FeSi-75','ферспл FeV азот.', 'ферспл  FeV-80', 'ферспл  фх850А'], axis=1, inplace=True)
data.drop(['эл. энергия', 'температура последняя'], axis=1, inplace=True) # довольно точно совпадает с t под током
# t последняя спорно
# вернём 'ферспл  Mn5Si65Al0.5', 'ферспл SiMn18',
#удалим лишние химстали

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6444 entries, 0 to 7040
# Data columns (total 66 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   МАРКА                    6444 non-null   object
#  1   t вып-обр                6444 non-null   float64
#  2   t обработка              6440 non-null   float64
#  3   t под током              6440 non-null   float64
#  4   t продувка               6444 non-null   float64
#  5   ПСН гр.                  5249 non-null   float64
#  6   чист расход C            6435 non-null   float64
#  7   чист расход Cr           5883 non-null   float64
#  8   чист расход Mn           6431 non-null   float64
#  9   чист расход Si           6431 non-null   float64
#  10  чист расход V            6178 non-null   float64
#  11  температура первая       6436 non-null   float64
#  12  Ar (интенс.)             6426 non-null   float64
#  13  N2 (интенс.)             1389 non-null   float64
#  14  эл. энергия (интенс.)    6440 non-null   float64
#  15  произв жидкая сталь      6444 non-null   float64
#  16  расход газ Ar            6426 non-null   float64
#  17  расход газ  N2           1389 non-null   float64
#  18  сыпуч известь РП         4770 non-null   float64
#  19  сыпуч  шпат плав.        5910 non-null   float64
#  20  ферспл CaC2              6244 non-null   float64
#  21  ферспл FeMo              33 non-null     float64
#  22  ферспл  Mn5Si65Al0.5     6400 non-null   float64
#  23  ферспл  Ni H1 пласт.     82 non-null     float64
#  24  ферспл SiMn18            6398 non-null   float64
#  25  химсталь первый Al_1     6444 non-null   float64
#  26  химсталь первый C_1      6444 non-null   float64
#  27  химсталь первый Cr_1     6444 non-null   float64
#  28  химсталь первый Cu_1     6444 non-null   float64
#  29  химсталь первый Mn_1     6444 non-null   float64
#  30  химсталь первый Mo_1     6443 non-null   float64
#  31  химсталь первый N_1      6443 non-null   float64
#  32  химсталь первый Ni_1     6444 non-null   float64
#  33  химсталь первый P_1      6444 non-null   float64
#  34  химсталь первый S_1      6444 non-null   float64
#  35  химсталь первый Si_1     6444 non-null   float64
#  36  химсталь первый Ti_1     6444 non-null   float64
#  37  химсталь первый V_1      6444 non-null   float64
#  38  химсталь последний Al    6444 non-null   float64
#  39  химсталь последний C     6444 non-null   float64
#  40  химсталь последний Ca    6218 non-null   float64
#  41  химсталь последний Cr    6444 non-null   float64
#  42  химсталь последний Cu    6444 non-null   float64
#  43  химсталь последний Mn    6444 non-null   float64
#  44  химсталь последний Mo    6444 non-null   float64
#  45  химсталь последний N     6442 non-null   float64
#  46  химсталь последний Ni    6444 non-null   float64
#  47  химсталь последний P     6444 non-null   float64
#  48  химсталь последний S     6444 non-null   float64
#  49  химсталь последний Si    6444 non-null   float64
#  50  химсталь последний Ti    6444 non-null   float64
#  51  химсталь последний V     6444 non-null   float64
#  52  химшлак первый Al2O3_1   4742 non-null   float64
#  53  химшлак первый CaO_1     6444 non-null   float64
#  54  химшлак первый FeO_1     6444 non-null   float64
#  55  химшлак первый MgO_1     6443 non-null   float64
#  56  химшлак первый MnO_1     6444 non-null   float64
#  57  химшлак первый R_1       6444 non-null   float64
#  58  химшлак первый SiO2_1    4742 non-null   float64
#  59  химшлак последний Al2O3  4742 non-null   float64
#  60  химшлак последний CaO    6444 non-null   float64
#  61  химшлак последний FeO    6444 non-null   float64
#  62  химшлак последний MgO    6443 non-null   float64
#  63  химшлак последний MnO    6444 non-null   float64
#  64  химшлак последний R      6444 non-null   float64
#  65  химшлак последний SiO2   4742 non-null   float64
# dtypes: float64(65), object(1)
# memory usage: 3.3+ MB

# %%
marks = data['МАРКА'].unique()
marks
# Out:
# array(['Э76ХФ', 'Э73Ф', 'Э90ХАФ', 'G2HH', 'Э76', 'Э76Ф', '900А', 'Э76ХАФ',
#        'R350HT', 'НХ', 'R260', 'Ш2.2', 'Ш2Л', 'С255', 'С345', 'С355',
#        '09Г2С'], dtype=object)

# %%
dict_marks_df = {}

for mark in marks:
    dict_marks_df[mark] = data[data['МАРКА'] == mark]
    dict_marks_df[mark].drop(['МАРКА'], axis=1, inplace=True)

# %%
dict_marks_df['Э76ХФ'].head()
# Out:
#    t вып-обр  t обработка  t под током  t продувка  ПСН гр.  чист расход C  \
# 0       29.0    45.366667    24.400000   41.033333      NaN       0.456460
# 1       26.0    44.066667    13.866667   44.066667      NaN       0.359285
# 2       24.0    43.350000    17.950000   43.350000      NaN       0.331665
# 3       17.0    46.183333    19.816667   46.183333      NaN       0.377945
# 4       20.0    48.500000    17.033333   48.500000      NaN       0.389875
#
#    чист расход Cr  чист расход Mn  чист расход Si  чист расход V  \
# 0        0.059572        0.117446        0.104762       0.040938
# 1        0.083738        0.160923        0.110327       0.040083
# 2        0.081490        0.132332        0.139860       0.041622
# 3        0.133194        0.221605        0.165186       0.042050
# 4        0.105094        0.169459        0.143024       0.040967
#
#    температура первая  Ar (интенс.)  N2 (интенс.)  эл. энергия (интенс.)  \
# 0              1557.0     13.606742           NaN           12809.016393
# 1              1601.0      8.074721           NaN           12816.346154
# 2              1593.0     13.801968           NaN           12511.420613
# 3              1589.0     12.664959           NaN           12998.149706
# 4              1597.0     10.298350           NaN           12987.475538
#
#    произв жидкая сталь  расход газ Ar  расход газ  N2  сыпуч известь РП  \
# 0                115.5         18.611             NaN               NaN
# 1                111.6         11.659             NaN               NaN
# 2                115.8         19.871             NaN               NaN
# 3                116.3         19.497             NaN             0.077
# 4                115.0         16.649             NaN             0.082
#
#    сыпуч  шпат плав.  ферспл CaC2  ферспл FeMo  ферспл  Mn5Si65Al0.5  \
# 0              0.123         0.02          NaN                 0.112
# 1              0.094         0.02          NaN                 0.102
# 2              0.061         0.02          NaN                 0.160
# 3              0.059         0.02          NaN                 0.161
# 4              0.035         0.02          NaN                 0.149
#
#    ферспл  Ni H1 пласт.  ферспл SiMn18  химсталь первый Al_1  \
# 0                   NaN          0.182                 0.002
# 1                   NaN          0.251                 0.002
# 2                   NaN          0.204                 0.002
# 3                   NaN          0.345                 0.002
# 4                   NaN          0.263                 0.002
#
#    химсталь первый C_1  химсталь первый Cr_1  химсталь первый Cu_1  \
# 0                0.389                 0.368                 0.127
# 1                0.465                 0.345                 0.112
# 2                0.513                 0.351                 0.107
# 3                0.487                 0.310                 0.105
# 4                0.461                 0.334                 0.105
#
#    химсталь первый Mn_1  химсталь первый Mo_1  химсталь первый N_1  \
# 0                 0.682                 0.010                0.011
# 1                 0.643                 0.009                0.011
# 2                 0.674                 0.007                0.011
# 3                 0.611                 0.009                0.011
# 4                 0.652                 0.007                0.011
#
#    химсталь первый Ni_1  химсталь первый P_1  химсталь первый S_1  \
# 0                 0.086                0.009                0.023
# 1                 0.080                0.007                0.023
# 2                 0.078                0.008                0.019
# 3                 0.070                0.006                0.020
# 4                 0.080                0.007                0.020
#
#    химсталь первый Si_1  химсталь первый Ti_1  химсталь первый V_1  \
# 0                 0.459                 0.002                0.002
# 1                 0.461                 0.002                0.002
# 2                 0.455                 0.002                0.002
# 3                 0.434                 0.001                0.001
# 4                 0.447                 0.001                0.002
#
#    химсталь последний Al  химсталь последний C  химсталь последний Ca  \
# 0                  0.003                 0.756                 0.0001
# 1                  0.003                 0.774                 0.0003
# 2                  0.004                 0.770                 0.0009
# 3                  0.003                 0.767                 0.0002
# 4                  0.003                 0.784                 0.0003
#
#    химсталь последний Cr  химсталь последний Cu  химсталь последний Mn  \
# 0                  0.417                  0.126                  0.779
# 1                  0.416                  0.109                  0.767
# 2                  0.417                  0.108                  0.788
# 3                  0.419                  0.103                  0.795
# 4                  0.421                  0.105                  0.796
#
#    химсталь последний Mo  химсталь последний N  химсталь последний Ni  \
# 0                  0.009                 0.012                  0.086
# 1                  0.008                 0.013                  0.079
# 2                  0.006                 0.012                  0.078
# 3                  0.008                 0.013                  0.070
# 4                  0.006                 0.013                  0.081
#
#    химсталь последний P  химсталь последний S  химсталь последний Si  \
# 0                 0.011                 0.018                  0.559
# 1                 0.008                 0.021                  0.543
# 2                 0.008                 0.013                  0.568
# 3                 0.007                 0.014                  0.571
# 4                 0.008                 0.017                  0.568
#
#    химсталь последний Ti  химсталь последний V  химшлак первый Al2O3_1  \
# 0                  0.003                 0.037                     NaN
# 1                  0.003                 0.038                     NaN
# 2                  0.003                 0.038                     NaN
# 3                  0.003                 0.038                     NaN
# 4                  0.003                 0.037                     NaN
#
#    химшлак первый CaO_1  химшлак первый FeO_1  химшлак первый MgO_1  \
# 0                  63.7                   1.1                   3.7
# 1                  58.5                   0.8                   4.9
# 2                  58.0                   0.8                   8.6
# 3                  59.8                   0.4                   6.4
# 4                  59.6                   0.7                   4.7
#
#    химшлак первый MnO_1  химшлак первый R_1  химшлак первый SiO2_1  \
# 0                  0.12                 2.6                    NaN
# 1                  0.14                 2.2                    NaN
# 2                  0.12                 2.6                    NaN
# 3                  0.11                 2.4                    NaN
# 4                  0.12                 2.4                    NaN
#
#    химшлак последний Al2O3  химшлак последний CaO  химшлак последний FeO  \
# 0                      NaN                   53.4                    1.0
# 1                      NaN                   59.3                    0.6
# 2                      NaN                   57.2                    0.5
# 3                      NaN                   60.3                    0.5
# 4                      NaN                   60.3                    0.6
#
#    химшлак последний MgO  химшлак последний MnO  химшлак последний R  \
# 0                    5.8                   0.15                  2.6
# 1                    4.1                   0.11                  2.3
# 2                    8.1                   0.13                  2.3
# 3                    6.3                   0.12                  2.6
# 4                    4.5                   0.09                  2.5
#
#    химшлак последний SiO2
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN

# %%
def description_nulls(features, bin=20):
    null_list = []
    for name in features.columns:
        if features[name].isna().sum() / features.shape[0] == 1:
            print(name)
            null_list.append(name)
    return null_list

# %%
for mark in marks:
    print("---------------------\n", mark)
    null_list = description_nulls(dict_marks_df[mark].iloc[:, 1:])
    dict_marks_df[mark].drop(null_list, axis=1, inplace=True)
# Out:
# ---------------------
#  Э76ХФ
# N2 (интенс.)
# расход газ  N2
# ферспл FeMo
# ферспл  Ni H1 пласт.
# ---------------------
#  Э73Ф
# чист расход Cr
# N2 (интенс.)
# расход газ  N2
# ферспл FeMo
# ферспл  Ni H1 пласт.
# ---------------------
#  Э90ХАФ
# ферспл FeMo
# ферспл  Ni H1 пласт.
# ---------------------
#  G2HH
# чист расход V
# N2 (интенс.)
# расход газ  N2
# ---------------------
#  Э76
# N2 (интенс.)
# расход газ  N2
# ферспл FeMo
# ферспл  Ni H1 пласт.
# ---------------------
#  Э76Ф
# N2 (интенс.)
# расход газ  N2
# ферспл FeMo
# ферспл  Ni H1 пласт.
# ---------------------
#  900А
# чист расход Cr
# чист расход V
# N2 (интенс.)
# расход газ  N2
# ферспл FeMo
# ферспл  Ni H1 пласт.
# химшлак первый Al2O3_1
# химшлак первый SiO2_1
# химшлак последний Al2O3
# химшлак последний SiO2
# ---------------------
#  Э76ХАФ
# ферспл FeMo
# ---------------------
#  R350HT
# чист расход Cr
# N2 (интенс.)
# расход газ  N2
# ферспл FeMo
# ферспл  Ni H1 пласт.
# ---------------------
#  НХ
# ферспл FeMo
# ферспл  Ni H1 пласт.
# ---------------------
#  R260
# чист расход Cr
# чист расход V
# N2 (интенс.)
# расход газ  N2
# ферспл FeMo
# ферспл  Ni H1 пласт.
# ---------------------
#  Ш2.2
# чист расход Cr
# чист расход V
# N2 (интенс.)
# расход газ  N2
# ферспл FeMo
# ферспл  Ni H1 пласт.
# ---------------------
#  Ш2Л
# чист расход V
# N2 (интенс.)
# расход газ  N2
# ферспл FeMo
# ферспл  Ni H1 пласт.
# ---------------------
#  С255
# чист расход Cr
# чист расход V
# N2 (интенс.)
# расход газ  N2
# сыпуч  шпат плав.
# ферспл CaC2
# ферспл FeMo
# ферспл  Ni H1 пласт.
# химсталь последний Ca
# ---------------------
#  С345
# чист расход Cr
# чист расход V
# N2 (интенс.)
# расход газ  N2
# сыпуч  шпат плав.
# ферспл CaC2
# ферспл FeMo
# ферспл  Ni H1 пласт.
# химсталь последний Ca
# ---------------------
#  С355
# чист расход Cr
# чист расход V
# N2 (интенс.)
# расход газ  N2
# сыпуч  шпат плав.
# ферспл CaC2
# ферспл FeMo
# ферспл  Ni H1 пласт.
# химсталь последний Ca
# ---------------------
#  09Г2С
# чист расход Cr
# чист расход V
# N2 (интенс.)
# расход газ  N2
# сыпуч  шпат плав.
# ферспл CaC2
# ферспл FeMo
# ферспл  Ni H1 пласт.
# химсталь первый Mo_1
# химсталь последний Ca

# %%
def description_graphs(features, bin=20):
    for name in features.columns:
        if features[name].isna().sum() == len(features[name]):
            print(name, '- пустой столбец')
            continue      
        print(name, '\nПропущенных значений:', features[name].isna().sum(),\
              '(', round(features[name].isna().sum() * 100 / len(features[name]), 2)  ,'%)',
             '\nМедиана: {2}, Среднее значение: {0}, Ср.откл:{1}'.format(round(features[name].mean(), 3),\
                                                                         round(features[name].std(), 3),\
                                                                         features[name].median()), '\n')
        fig = plt.figure(figsize=(10, 8))
        plt.subplot(221)
        plt.hist(features[name], bins=bin)
        plt.grid()
        plt.subplot(222)
        sns.boxplot(y=features[name])
        plt.show()

# %%
description_graphs(dict_marks_df['Э76ХФ'])
# Out:
# t вып-обр
# Пропущенных значений: 0 ( 0.0 %)
# Медиана: 25.0, Среднее значение: 25.796, Ср.откл:14.465
# t обработка
# Пропущенных значений: 3 ( 0.07 %)
# Медиана: 44.1666667, Среднее значение: 45.747, Ср.откл:10.003
# t под током
# Пропущенных значений: 3 ( 0.07 %)
# Медиана: 20.216666699999998, Среднее значение: 20.743, Ср.откл:4.583
# t продувка
# Пропущенных значений: 0 ( 0.0 %)
# Медиана: 44.05833335, Среднее значение: 45.667, Ср.откл:9.693
# ПСН гр.
# Пропущенных значений: 842 ( 19.0 %)
# Медиана: 3.0, Среднее значение: 2.98, Ср.откл:0.732
# чист расход C
# Пропущенных значений: 6 ( 0.14 %)
# Медиана: 0.3773944, Среднее значение: 0.376, Ср.откл:0.076
# чист расход Cr
# Пропущенных значений: 15 ( 0.34 %)
# Медиана: 0.12584, Среднее значение: 0.125, Ср.откл:0.027
# чист расход Mn
# Пропущенных значений: 9 ( 0.2 %)
# Медиана: 0.133436, Среднее значение: 0.134, Ср.откл:0.049
# чист расход Si
# Пропущенных значений: 9 ( 0.2 %)
# Медиана: 0.13431300000000002, Среднее значение: 0.137, Ср.откл:0.039
# чист расход V
# Пропущенных значений: 18 ( 0.41 %)
# Медиана: 0.039631099999999995, Среднее значение: 0.04, Ср.откл:0.002
# температура первая
# Пропущенных значений: 4 ( 0.09 %)
# Медиана: 1568.0, Среднее значение: 1567.722, Ср.откл:22.184
# Ar (интенс.)
# Пропущенных значений: 0 ( 0.0 %)
# Медиана: 10.778037849999999, Среднее значение: 11.345, Ср.откл:3.447
# эл. энергия (интенс.)
# Пропущенных значений: 3 ( 0.07 %)
# Медиана: 13031.123139399999, Среднее значение: 12980.913, Ср.откл:899.391
# произв жидкая сталь
# Пропущенных значений: 0 ( 0.0 %)
# Медиана: 114.6, Среднее значение: 114.477, Ср.откл:2.4
# расход газ Ar
# Пропущенных значений: 0 ( 0.0 %)
# Медиана: 16.1055, Среднее значение: 16.996, Ср.откл:5.628
# сыпуч известь РП
# Пропущенных значений: 1148 ( 25.9 %)
# Медиана: 0.11599999999999999, Среднее значение: 0.13, Ср.откл:0.076
# сыпуч  шпат плав.
# Пропущенных значений: 316 ( 7.13 %)
# Медиана: 0.048, Среднее значение: 0.054, Ср.откл:0.023
# ферспл CaC2
# Пропущенных значений: 126 ( 2.84 %)
# Медиана: 0.02, Среднее значение: 0.02, Ср.откл:0.001
# ферспл  Mn5Si65Al0.5
# Пропущенных значений: 15 ( 0.34 %)
# Медиана: 0.152, Среднее значение: 0.155, Ср.откл:0.051
# ферспл SiMn18
# Пропущенных значений: 30 ( 0.68 %)
# Медиана: 0.20600000000000002, Среднее значение: 0.207, Ср.откл:0.075
# химсталь первый Al_1
# Пропущенных значений: 0 ( 0.0 %)
# Медиана: 0.002, Среднее значение: 0.002, Ср.откл:0.0
# химсталь первый C_1
# Пропущенных значений: 0 ( 0.0 %)
# Медиана: 0.47, Среднее значение: 0.473, Ср.откл:0.058
# химсталь первый Cr_1
# Пропущенных значений: 0 ( 0.0 %)
# Медиана: 0.312, Среднее значение: 0.313, Ср.откл:0.023
# химсталь первый Cu_1
# Пропущенных значений: 0 ( 0.0 %)
# Медиана: 0.10300000000000001, Среднее значение: 0.102, Ср.откл:0.013
# химсталь первый Mn_1
# Пропущенных значений: 0 ( 0.0 %)
# Медиана: 0.6709999999999999, Среднее значение: 0.671, Ср.откл:0.042
# химсталь первый Mo_1
# Пропущенных значений: 0 ( 0.0 %)
# Медиана: 0.006999999999999999, Среднее значение: 0.007, Ср.откл:0.002
# химсталь первый N_1
# Пропущенных значений: 1 ( 0.02 %)
# Медиана: 0.01, Среднее значение: 0.01, Ср.откл:0.001
# химсталь первый Ni_1
# Пропущенных значений: 0 ( 0.0 %)
# Медиана: 0.071, Среднее значение: 0.071, Ср.откл:0.01
# химсталь первый P_1
# Пропущенных значений: 0 ( 0.0 %)
# Медиана: 0.009000000000000001, Среднее значение: 0.009, Ср.откл:0.002
# химсталь первый S_1
# Пропущенных значений: 0 ( 0.0 %)
# Медиана: 0.02, Среднее значение: 0.02, Ср.откл:0.003
# химсталь первый Si_1
# Пропущенных значений: 0 ( 0.0 %)
# Медиана: 0.451, Среднее значение: 0.449, Ср.откл:0.03
# химсталь первый Ti_1
# Пропущенных значений: 0 ( 0.0 %)
# Медиана: 0.002, Среднее значение: 0.002, Ср.откл:0.001
# химсталь первый V_1
# Пропущенных значений: 0 ( 0.0 %)
# Медиана: 0.003, Среднее значение: 0.003, Ср.откл:0.003
# химсталь последний Al
# Пропущенных значений: 0 ( 0.0 %)
# Медиана: 0.003, Среднее значение: 0.003, Ср.откл:0.001
# химсталь последний C
# Пропущенных значений: 0 ( 0.0 %)
# Медиана: 0.767, Среднее значение: 0.767, Ср.откл:0.013
# химсталь последний Ca
# Пропущенных значений: 127 ( 2.87 %)
# Медиана: 0.0003, Среднее значение: 0.0, Ср.откл:0.0
# химсталь последний Cr
# Пропущенных значений: 0 ( 0.0 %)
# Медиана: 0.41700000000000004, Среднее значение: 0.417, Ср.откл:0.004
# химсталь последний Cu
# Пропущенных значений: 0 ( 0.0 %)
# Медиана: 0.102, Среднее значение: 0.102, Ср.откл:0.012
# химсталь последний Mn
# Пропущенных значений: 0 ( 0.0 %)
# Медиана: 0.7879999999999999, Среднее значение: 0.788, Ср.откл:0.007
# химсталь последний Mo
# Пропущенных значений: 0 ( 0.0 %)
# Медиана: 0.006, Среднее значение: 0.006, Ср.откл:0.002
# химсталь последний N
# Пропущенных значений: 2 ( 0.05 %)
# Медиана: 0.012, Среднее значение: 0.012, Ср.откл:0.002
# химсталь последний Ni
# Пропущенных значений: 0 ( 0.0 %)
# Медиана: 0.071, Среднее значение: 0.071, Ср.откл:0.01
# химсталь последний P
# Пропущенных значений: 0 ( 0.0 %)
# Медиана: 0.01, Среднее значение: 0.01, Ср.откл:0.002
# химсталь последний S
# Пропущенных значений: 0 ( 0.0 %)
# Медиана: 0.015, Среднее значение: 0.015, Ср.откл:0.003
# химсталь последний Si
# Пропущенных значений: 0 ( 0.0 %)
# Медиана: 0.565, Среднее значение: 0.565, Ср.откл:0.01
# химсталь последний Ti
# Пропущенных значений: 0 ( 0.0 %)
# Медиана: 0.003, Среднее значение: 0.003, Ср.откл:0.0
# химсталь последний V
# Пропущенных значений: 0 ( 0.0 %)
# Медиана: 0.037000000000000005, Среднее значение: 0.037, Ср.откл:0.001
# химшлак первый Al2O3_1
# Пропущенных значений: 1168 ( 26.35 %)
# Медиана: 4.0, Среднее значение: 4.087, Ср.откл:0.857
# химшлак первый CaO_1
# Пропущенных значений: 0 ( 0.0 %)
# Медиана: 54.7, Среднее значение: 54.536, Ср.откл:5.001
# химшлак первый FeO_1
# Пропущенных значений: 0 ( 0.0 %)
# Медиана: 0.6, Среднее значение: 0.674, Ср.откл:0.611
# химшлак первый MgO_1
# Пропущенных значений: 1 ( 0.02 %)
# Медиана: 11.3, Среднее значение: 11.552, Ср.откл:3.496
# химшлак первый MnO_1
# Пропущенных значений: 0 ( 0.0 %)
# Медиана: 0.14, Среднее значение: 0.199, Ср.откл:0.205
# химшлак первый R_1
# Пропущенных значений: 0 ( 0.0 %)
# Медиана: 2.4, Среднее значение: 2.408, Ср.откл:0.317
# химшлак первый SiO2_1
# Пропущенных значений: 1168 ( 26.35 %)
# Медиана: 22.8, Среднее значение: 22.754, Ср.откл:2.381
# химшлак последний Al2O3
# Пропущенных значений: 1168 ( 26.35 %)
# Медиана: 4.4, Среднее значение: 4.533, Ср.откл:0.956
# химшлак последний CaO
# Пропущенных значений: 0 ( 0.0 %)
# Медиана: 56.9, Среднее значение: 56.501, Ср.откл:3.756
# химшлак последний FeO
# Пропущенных значений: 0 ( 0.0 %)
# Медиана: 0.6, Среднее значение: 0.584, Ср.откл:0.213
# химшлак последний MgO
# Пропущенных значений: 1 ( 0.02 %)
# Медиана: 8.9, Среднее значение: 9.023, Ср.откл:3.171
# химшлак последний MnO
# Пропущенных значений: 0 ( 0.0 %)
# Медиана: 0.11, Среднее значение: 0.12, Ср.откл:0.058
# химшлак последний R
# Пропущенных значений: 0 ( 0.0 %)
# Медиана: 2.3, Среднее значение: 2.36, Ср.откл:0.223
# химшлак последний SiO2
# Пропущенных значений: 1168 ( 26.35 %)
# Медиана: 24.6, Среднее значение: 24.037, Ср.откл:2.178

# %%
# Заменить все сыпучие null на 0
# Удалили все чистые добавки
# Посмотреть ещё на корелляции в других группах
# В распределениях появились интересные закономерности, а может систематические ошибки (Ti)
# При разбитии сталей на марки появилось много просто null признаков, например можно удалить вообще ВСЁ 
# про молибден, попробовать
# Видно, что на марке Э76ХФ

# %%
big_steel = dict_marks_df['Э76ХФ']

# %%
big_steel.shape
# Out:
# (4432, 61)

# %%
big_steel = big_steel[big_steel['химшлак первый Al2O3_1'].notna()]

big_steel.shape
# Out:
# (3264, 61)

# %%
big_steel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3264 entries, 589 to 7026
# Data columns (total 61 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   t вып-обр                3264 non-null   float64
#  1   t обработка              3262 non-null   float64
#  2   t под током              3263 non-null   float64
#  3   t продувка               3264 non-null   float64
#  4   ПСН гр.                  2610 non-null   float64
#  5   чист расход C            3260 non-null   float64
#  6   чист расход Cr           3254 non-null   float64
#  7   чист расход Mn           3258 non-null   float64
#  8   чист расход Si           3258 non-null   float64
#  9   чист расход V            3250 non-null   float64
#  10  температура первая       3261 non-null   float64
#  11  Ar (интенс.)             3264 non-null   float64
#  12  эл. энергия (интенс.)    3263 non-null   float64
#  13  произв жидкая сталь      3264 non-null   float64
#  14  расход газ Ar            3264 non-null   float64
#  15  сыпуч известь РП         2598 non-null   float64
#  16  сыпуч  шпат плав.        2979 non-null   float64
#  17  ферспл CaC2              3159 non-null   float64
#  18  ферспл  Mn5Si65Al0.5     3257 non-null   float64
#  19  ферспл SiMn18            3241 non-null   float64
#  20  химсталь первый Al_1     3264 non-null   float64
#  21  химсталь первый C_1      3264 non-null   float64
#  22  химсталь первый Cr_1     3264 non-null   float64
#  23  химсталь первый Cu_1     3264 non-null   float64
#  24  химсталь первый Mn_1     3264 non-null   float64
#  25  химсталь первый Mo_1     3264 non-null   float64
#  26  химсталь первый N_1      3263 non-null   float64
#  27  химсталь первый Ni_1     3264 non-null   float64
#  28  химсталь первый P_1      3264 non-null   float64
#  29  химсталь первый S_1      3264 non-null   float64
#  30  химсталь первый Si_1     3264 non-null   float64
#  31  химсталь первый Ti_1     3264 non-null   float64
#  32  химсталь первый V_1      3264 non-null   float64
#  33  химсталь последний Al    3264 non-null   float64
#  34  химсталь последний C     3264 non-null   float64
#  35  химсталь последний Ca    3172 non-null   float64
#  36  химсталь последний Cr    3264 non-null   float64
#  37  химсталь последний Cu    3264 non-null   float64
#  38  химсталь последний Mn    3264 non-null   float64
#  39  химсталь последний Mo    3264 non-null   float64
#  40  химсталь последний N     3262 non-null   float64
#  41  химсталь последний Ni    3264 non-null   float64
#  42  химсталь последний P     3264 non-null   float64
#  43  химсталь последний S     3264 non-null   float64
#  44  химсталь последний Si    3264 non-null   float64
#  45  химсталь последний Ti    3264 non-null   float64
#  46  химсталь последний V     3264 non-null   float64
#  47  химшлак первый Al2O3_1   3264 non-null   float64
#  48  химшлак первый CaO_1     3264 non-null   float64
#  49  химшлак первый FeO_1     3264 non-null   float64
#  50  химшлак первый MgO_1     3263 non-null   float64
#  51  химшлак первый MnO_1     3264 non-null   float64
#  52  химшлак первый R_1       3264 non-null   float64
#  53  химшлак первый SiO2_1    3264 non-null   float64
#  54  химшлак последний Al2O3  3264 non-null   float64
#  55  химшлак последний CaO    3264 non-null   float64
#  56  химшлак последний FeO    3264 non-null   float64
#  57  химшлак последний MgO    3263 non-null   float64
#  58  химшлак последний MnO    3264 non-null   float64
#  59  химшлак последний R      3264 non-null   float64
#  60  химшлак последний SiO2   3264 non-null   float64
# dtypes: float64(61)
# memory usage: 1.5 MB

# %%
big_steel = big_steel.fillna(value=dict.fromkeys(['ферспл  Mn5Si65Al0.5', 'ферспл SiMn18', 'чист расход C', 'чист расход Cr', 'чист расход Mn', 'чист расход Si', 'чист расход V', 'расход газ Ar', 'сыпуч известь РП', 'сыпуч  шпат плав.', 'ферспл CaC2'], 0))
for col in ['t обработка', 't под током', 'температура первая', 'эл. энергия (интенс.)', 'химшлак первый MgO_1']:
    big_steel = big_steel[big_steel[col].notna()]
for col in big_steel.iloc[:, 18:45].columns:
    big_steel = big_steel[big_steel[col].notna()]
big_steel = big_steel.fillna(value=dict.fromkeys(['ПСН гр.'], big_steel['ПСН гр.'].median()))

#big_steel = big_steel.fillna(value=dict.fromkeys(['химшлак первый Al2O3_1'], big_steel['химшлак первый Al2O3_1'].mean()))
#big_steel = big_steel.fillna(value=dict.fromkeys(['химшлак первый SiO2_1'], big_steel['химшлак первый SiO2_1'].mean()))
#big_steel = big_steel.fillna(value=dict.fromkeys(['химшлак последний Al2O3'], big_steel['химшлак последний Al2O3'].mean()))
#big_steel = big_steel.fillna(value=dict.fromkeys(['химшлак последний SiO2'], big_steel['химшлак последний SiO2'].mean()))

big_steel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3166 entries, 1345 to 7026
# Data columns (total 61 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   t вып-обр                3166 non-null   float64
#  1   t обработка              3166 non-null   float64
#  2   t под током              3166 non-null   float64
#  3   t продувка               3166 non-null   float64
#  4   ПСН гр.                  3166 non-null   float64
#  5   чист расход C            3166 non-null   float64
#  6   чист расход Cr           3166 non-null   float64
#  7   чист расход Mn           3166 non-null   float64
#  8   чист расход Si           3166 non-null   float64
#  9   чист расход V            3166 non-null   float64
#  10  температура первая       3166 non-null   float64
#  11  Ar (интенс.)             3166 non-null   float64
#  12  эл. энергия (интенс.)    3166 non-null   float64
#  13  произв жидкая сталь      3166 non-null   float64
#  14  расход газ Ar            3166 non-null   float64
#  15  сыпуч известь РП         3166 non-null   float64
#  16  сыпуч  шпат плав.        3166 non-null   float64
#  17  ферспл CaC2              3166 non-null   float64
#  18  ферспл  Mn5Si65Al0.5     3166 non-null   float64
#  19  ферспл SiMn18            3166 non-null   float64
#  20  химсталь первый Al_1     3166 non-null   float64
#  21  химсталь первый C_1      3166 non-null   float64
#  22  химсталь первый Cr_1     3166 non-null   float64
#  23  химсталь первый Cu_1     3166 non-null   float64
#  24  химсталь первый Mn_1     3166 non-null   float64
#  25  химсталь первый Mo_1     3166 non-null   float64
#  26  химсталь первый N_1      3166 non-null   float64
#  27  химсталь первый Ni_1     3166 non-null   float64
#  28  химсталь первый P_1      3166 non-null   float64
#  29  химсталь первый S_1      3166 non-null   float64
#  30  химсталь первый Si_1     3166 non-null   float64
#  31  химсталь первый Ti_1     3166 non-null   float64
#  32  химсталь первый V_1      3166 non-null   float64
#  33  химсталь последний Al    3166 non-null   float64
#  34  химсталь последний C     3166 non-null   float64
#  35  химсталь последний Ca    3166 non-null   float64
#  36  химсталь последний Cr    3166 non-null   float64
#  37  химсталь последний Cu    3166 non-null   float64
#  38  химсталь последний Mn    3166 non-null   float64
#  39  химсталь последний Mo    3166 non-null   float64
#  40  химсталь последний N     3166 non-null   float64
#  41  химсталь последний Ni    3166 non-null   float64
#  42  химсталь последний P     3166 non-null   float64
#  43  химсталь последний S     3166 non-null   float64
#  44  химсталь последний Si    3166 non-null   float64
#  45  химсталь последний Ti    3166 non-null   float64
#  46  химсталь последний V     3166 non-null   float64
#  47  химшлак первый Al2O3_1   3166 non-null   float64
#  48  химшлак первый CaO_1     3166 non-null   float64
#  49  химшлак первый FeO_1     3166 non-null   float64
#  50  химшлак первый MgO_1     3166 non-null   float64
#  51  химшлак первый MnO_1     3166 non-null   float64
#  52  химшлак первый R_1       3166 non-null   float64
#  53  химшлак первый SiO2_1    3166 non-null   float64
#  54  химшлак последний Al2O3  3166 non-null   float64
#  55  химшлак последний CaO    3166 non-null   float64
#  56  химшлак последний FeO    3166 non-null   float64
#  57  химшлак последний MgO    3166 non-null   float64
#  58  химшлак последний MnO    3166 non-null   float64
#  59  химшлак последний R      3166 non-null   float64
#  60  химшлак последний SiO2   3166 non-null   float64
# dtypes: float64(61)
# memory usage: 1.5 MB

# %%
corr_matrix = big_steel.corr()
corr_matrix = corr_matrix[np.abs(corr_matrix) > 0.7]

fig, ax = plt.subplots(figsize=(10,8))
ax = sns.heatmap(corr_matrix)

# %%
to_drop = ['химшлак последний Al2O3', 'химшлак последний CaO',
       'химшлак последний FeO', 'химшлак последний MgO',
       'химшлак последний MnO', 'химшлак последний R',
       'химшлак последний SiO2']
X = StandardScaler().fit_transform(big_steel.drop(to_drop, axis=1))

targets = ['химшлак последний CaO',
       'химшлак последний FeO', 'химшлак последний MgO',
       'химшлак последний MnO', 'химшлак последний R', 'химшлак последний Al2O3', 'химшлак последний SiO2']

# %%
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import make_scorer

for t in targets:
    y = big_steel[t] 
    lg_R = LinearRegression()
    score = cross_val_score(lg_R, X, y, scoring=make_scorer(mean_absolute_percentage_error), cv=5, ).mean()
    print(t, "\nmedian: ", y.median(), "\n", score * 100, "%")
# Out:
# химшлак последний CaO
# median:  56.7
#  4.896136405702575 %
# химшлак последний FeO
# median:  0.6
#  35.892955158029395 %
# химшлак последний MgO
# median:  9.3
#  26.57683514977537 %
# химшлак последний MnO
# median:  0.1
#  29.869560467805805 %
# химшлак последний R
# median:  2.3
#  6.209157883599272 %
# химшлак последний Al2O3
# median:  4.4
#  11.146978594306947 %
# химшлак последний SiO2
# median:  24.6
#  7.064050018075251 %

# %%
to_drop = ['химшлак последний Al2O3', 'химшлак последний CaO',
       'химшлак последний FeO', 'химшлак последний MgO',
       'химшлак последний MnO', 'химшлак последний R',
       'химшлак последний SiO2']

X = big_steel.drop(to_drop, axis=1)

targets = ['химшлак последний CaO',
       'химшлак последний FeO', 'химшлак последний MgO',
       'химшлак последний MnO', 'химшлак последний R', 'химшлак последний Al2O3', 'химшлак последний SiO2']

for i in range(len(targets)):
    best_score_t = ""
    best_score = 1
    best_pred = []
    for t in targets:
        y = big_steel[t] 
        lg_R = LinearRegression(normalize=True)
        score = cross_val_score(lg_R, X, y, scoring=make_scorer(mean_absolute_percentage_error), cv=5).mean()      
        
        if score < best_score:
            best_score_t = t
            best_score = score
    best_pred = LinearRegression(normalize=True).fit(X, y).predict(X)
    
    print(best_score_t, "\n", best_score * 100, "%")
    targets.remove(best_score_t)
    X[best_score_t] = best_pred
# Out:
# химшлак последний CaO
#  4.896136405702575 %
# химшлак последний R
#  6.209560085214823 %
# химшлак последний SiO2
#  7.067469022415541 %
# химшлак последний Al2O3
#  11.148073682288514 %
# химшлак последний MgO
#  26.62707705285237 %
# химшлак последний MnO
#  29.865302517088544 %
# химшлак последний FeO
#  35.954013560376154 %

# %%
from sklearn.ensemble import GradientBoostingRegressor

to_drop = ['химшлак последний Al2O3', 'химшлак последний CaO',
       'химшлак последний FeO', 'химшлак последний MgO',
       'химшлак последний MnO', 'химшлак последний R',
       'химшлак последний SiO2']

X = big_steel.drop(to_drop, axis=1)

targets = ['химшлак последний CaO',
       'химшлак последний FeO', 'химшлак последний MgO',
       'химшлак последний MnO', 'химшлак последний R', 'химшлак последний Al2O3', 'химшлак последний SiO2']

for i in range(len(targets)):
    best_score_t = ""
    best_score = 1
    best_pred = []
    for t in targets:
        y = big_steel[t] 
        reg = GradientBoostingRegressor(n_estimators=150, loss="lad", max_depth=4)
        score = cross_val_score(reg, X, y, scoring=make_scorer(mean_absolute_percentage_error), cv=5).mean()      
        
        if score < best_score:
            best_score_t = t
            best_score = score
    best_pred = GradientBoostingRegressor(n_estimators=150,  loss="lad", max_depth=4).fit(X, y).predict(X)
    
    print(best_score_t, "\n", best_score * 100, "%")
    targets.remove(best_score_t)
    X[best_score_t] = best_pred
# Out:
# химшлак последний CaO
#  4.974441927836529 %
# химшлак последний SiO2
#  5.076451114347043 %
# химшлак последний R
#  4.78512875389364 %
# химшлак последний Al2O3
#  7.749071606510574 %
# химшлак последний MgO
#  26.340669968190078 %
# химшлак последний MnO
#  17.48691987291357 %
# химшлак последний FeO
#  32.91617898295428 %
